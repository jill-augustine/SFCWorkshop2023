# %% [markdown]
# # Comparisons/Vergleiche

# %% [markdown]
# Symbol | Bedeutung
# --- | ---
# + | plus
# - | minus
# * | multiplizieren
# / | teilen
#
# Symbol | Prüfe | Ergebnis
# --- | --- | ---
# 3 == 7 | 3 ist gleich 7 | False
# != | 3 ist nicht gleich 7 | True
# 3 < 7 | 3 ist kleiner als 7 | True
# 3 > 7 | 3 ist größer als 7 | False
# 3 <= 7 | 3 ist kleiner oder gleich 7 | True
# 3 >= 7 | 3 ist größer oder gleich 7 | False

# %%
# TODO: Prüfe ob 99 größer ist als 4 * 25

antwort = 99 > (4 * 25)
print(antwort)
# Out:
# False

# %%
# TODO: Du willst Karten für ein Konzert kaufen. Prüfe ob genug Karten verfügbar sind

verfuegbare_karten = 16
gewuenschte_karten = 8

antwort = verfuegbare_karten >= gewuenschte_karten

print(antwort)
# Out:
# True

# %%
# TODO: Google die Bevölkerung von London, Wien und Berlin.
# Prüfe ob die Bevölkerung von London größer ist als die Bevölkerung von Wien

bevoelkerung_london =
bevoelkerung_wien =
bevoelkerung_berlin =

antwort = bevoelkerung_london > bevoelkerung_wien
print(antwort)

# %%
# Prüfe ob die Bevölkerung von London Wien und Berlin ingesamt größer ist als die Bevölkerung von London

antwort =
print(antwort)

# %% [markdown]
# ---
# # Quadrat

# %%
# Kopiert von "Exercise 1 - Intro"

seitenlaenge = float(input("Geb die Seite eines Quadrats in Zentimetern ein: "))
print("Der Umfang eines Quadrats mit einer Seitenlänge von", seitenlaenge, "cm beträgt", 4 * seitenlaenge, "cm")
print("Die Fläche eines Quadrats mit einer Seitenlänge von", seitenlaenge, "cm beträgt", seitenlaenge * seitenlaenge, "cm2")

# %%
# TODO: Definifere einen Variabel `ist_positiv`, der zeigt, ob `seitenlaenge` eine positive Zahl ist
# HINWEIS: "positiv" kann man als "größer als 0" beschreiben

seitenlange = 30

positive_zahl =

print("Seitenlaenge ist positiv:", positive_zahl)

# TODO: Ändere `seitenlaenge` auf andere Zahlen und lass den Code erneut laufen.

# %% [markdown]
# ---
# # If...else... / Wenn...sonst...
#
# Python | Deutsch | Englisch
# --- | --- | ---
# if | wenn | if
# elif | sonst wenn | or else if
# else | sonst | else

# %%
seitenlaenge = float(input("Geb die Seite eines Quadrats in Zentimetern ein: "))
positive_zahl = seitenlaenge > 0

if positive_zahl:
  print("Der Umfang eines Quadrats mit einer Seitenlänge von", seitenlaenge, "cm beträgt", 4 * seitenlaenge, "cm")
  print("Die Fläche eines Quadrats mit einer Seitenlänge von", seitenlaenge, "cm beträgt", seitenlaenge * seitenlaenge, "cm2")
else:
    print("Die Seitenlänge muss eine positive Zahl sein!")

print("Vielen Dank, dass du den geometrischen Rechner verwendest.")

# TODO: Lass das Code mehrmals laufen, gib verschiedene Werte für die Seitenlänge ein. Bemerke was geprintet ist.
# Out:
# Geb die Seite eines Quadrats in Zentimetern ein: 0
# Die Seitenlänge muss eine positive Zahl sein!
# Vielen Dank, dass du den geometrischen Rechner verwendest.

# %%
# DIESEN CODEBLOCK NICHT ÄNDERN ------------------------------------------------
from urllib.request import urlopen
url = "https://wttr.in/Vienna?format=%t"
temperatur_str = urlopen(url).read().decode()
if "°C" in temperatur_str:
  temperatur = int(temperatur_str.strip("°C"))
elif "°F" in temperatur_str:
  temperatur_f = int(temperatur_str.strip("°F"))
  temperatur = (temperatur_f / 32) * (5/9)
else:
  print("Die Temperatur konnte nicht berechnet werden.")
  temperatur = 25
print("Die aktuelle Temperature ist:", temperatur)
# ------------------------------------------------------------------------------

# TODO: Lass den Code laufen

if temperatur >= 20:
    print("Keine Jacke nötig, genieß die warmen Temperaturen")
elif temperatur >= 10:
    print("Leichte Jacke empfohlen")
else:
    print("Es ist eiskalt, du brauchst einen Wintermantel")

# Bei wieviel Grad brauchst du keine Jacke oder brauchst du einen Wintermantel?

# TODO: Passe die Zahlen `20` und `10` an und bermerke wie die Jacke empfehlung sich ändert.
# Out:
# Die aktuelle Temperature ist: 75
# Keine Jacke nötig, genieß die warmen Temperaturen

# %% [markdown]
# # Extra: Stein, Schere, Papier

# %%
# DIESEN CODEBLOCK NICHT ÄNDERN ------------------------------------------------
import random
options = ["Schere", "Stein", "Papier"]
valide_ergebnisse = ['Unentschieden', 'Du gewinnst!', 'Computer gewinnt!']
computer_choice = random.sample(options, 1)[0]
user_choice = input(f"Wähle eine Option ({', '.join(options)}): ")
# ------------------------------------------------------------------------------

# TODO: Vervollständige den Spiel "Schere, Stein, Papier". Prüfe, ob es funktioniert wie erwartet.

# HINWEISE:
# - Du muss noch 6 `elif`s hinzufügen
# - Das `&` Symbol funktioniert wie gesprochen
#   "If X and Y ... else if X und Z"
#   "Wenn X und Y ... sonst wenn X und Z"

if (user_choice == 'Stein') & (computer_choice == 'Stein'):
  ergebnis = 'Unentschieden'
elif (user_choice == 'Stein') & (computer_choice == 'Schere'):
  ergebnis = 'Du gewinnst!'
elif (user_choice == 'Stein') & (computer_choice == 'Papier'):
 ergebnis = 'Computer gewinnt!'
# TODO: Die extra `elif`s hier hinzufügen
else:
    ergebnis = 'Ich verstehe die Eingabe nicht: '+ user_choice

if ergebnis in valide_ergebnisse:
  print("Du hast gewählt:", user_choice)
  print("Computer hat gewählt:", computer_choice)
  print("Ergebnis:", ergebnis)
else:
  print(ergebnis)
