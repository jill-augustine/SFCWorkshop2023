# %% [markdown]
# ---
# # print

# %%
print(1,2,3)
print(1, 2, 3)
# Out:
# 1 2 3
# 1 2 3

# %%
print("Wien", "Salzburg", "Graz")
print("Wien", 123, "Graz", 456)
# Out:
# Wien Salzburg Graz
# Wien 123 Graz 456

# %%
# Print 7 + 3
print(7+3)
# Out:
# 10

# %%
#TODO: Print 18 / 5

# %%
# Print my name
print("Jillian Augustine")
# Out:
# Jillian Augustine

# %%
#TODO: Print your name

# %%
# Welche Tag ist heute?
#TODO: Ändere den Tag auf heute.

heute = "Mittwoch"
print(heute)
# Out:
# Mittwoch

# %% [markdown]
# ---
# ### Square

# %%
# 4 * 356
print("Der Umfang eines Quadrats mit einer Seitenlänge von 356 cm beträgt", 4 * 356, "cm")

# 356 * 356
print("Die Fläche eines Quadrats mit einer Seitenlänge von 356 cm beträgt", 356 * 356, "cm2")
# Out:
# Der Umfang eines Quadrats mit einer Seitenlänge von 356 cm beträgt 1424 cm
# Die Fläche eines Quadrats mit einer Seitenlänge von 356 cm beträgt 126736 cm2

# %%
#TODO: Versuche, den Code so zu ändern, dass es den Umfang und die Fläche eines Quadrats mit einer Seitenlänge von 123 cm berechnet.

#HINWEIS: 4 * ?
print("Der Umfang eines Quadrats mit einer Seitenlänge von 356 cm beträgt", 4 * 356, "cm")

#HINWEIS: ? * ?
print("Die Fläche eines Quadrats mit einer Seitenlänge von 356 cm beträgt", 356 * 356, "cm2")
# Out:
# Der Umfang eines Quadrats mit einer Seitenlänge von 356 cm beträgt 1424 cm
# Die Fläche eines Quadrats mit einer Seitenlänge von 356 cm beträgt 126736 cm2

# %% [markdown]
# ## Variabeln: `seitenlaenge`

# %%
seitenlaenge = 356

#HINWEIS: 4 * seitenlaenge
print("Der Umfang eines Quadrats mit einer Seitenlänge von", seitenlaenge, "cm beträgt", 4 * seitenlaenge, "cm")

#HINWEISE: seitenlaenge * seitenlaenge
print("Die Fläche eines Quadrats mit einer Seitenlänge von", seitenlaenge, "cm beträgt", seitenlaenge * seitenlaenge, "cm2")
# Out:
# Der Umfang eines Quadrats mit einer Seitenlänge von 356 cm beträgt 1424 cm
# Die Fläche eines Quadrats mit einer Seitenlänge von 356 cm beträgt 126736 cm2

# %% [markdown]
# # Input

# %%
text = input('Gib einen Text ein und drücke die Eingabetaste: ')
print("Du hast folgenden Text eingegeben:", text)
# Out:
# Gib einen Text ein und drücke die Eingabetaste: 89
# Du hast folgenden Text eingegeben: 89

# %%
seitenlaenge = float(input("Geb die Seite eines Quadrats in Zentimetern ein: "))
print("Du hast eine seitenlaenge von", seitenlaenge, "cm eingegeben.")
# Out:
# Geb die Seite eines Quadrats in Zentimetern ein: 890
# Du hast eine seitenlaenge von 890.0 cm eingegeben.

# %%
#TODO: Versuche das Code so zu schreiben, dass du die Länge der Seite des Quadrats über die Input eingibst. Printe dann die Umfang und Fläche des Quadrats.

#HINWEIS:
# - Du muss nur einen Teil des Codes von oben kopieren. Du muss keine neuen Codezeilen schreiben.
# - Kopiere die ganze Codezeile, die mit "seitenlaenge = float(input(" startet
# - Kopiere die zwei `print(...)` Codezeilen von dem Codeblock "Variabeln: Seitenlaenge"
