# %% [markdown]
# Reference: [ColabTurtle](https://github.com/tolgaatam/ColabTurtle)

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7641 sha256=e8f6bc4f4c88075574db71fa3507ea8b7d3292f99f5d8242ee0432e59cd41087
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle import Turtle
from ColabTurtle.Turtle import *
it = initializeTurtle

# %% [markdown]
# ## List of Turtle Commands
#
# ```
# back | background_color | backward | bgcolor | bk | clear | color | display | distance | down
#
# drawing_window | face | fd | forward | getheading | getx | gety | goto | heading | hideturtle
#
# home | ht | initializeTurtle | is_pen_down | is_turtle_visible | isdown | isvisible | left | lt | math
#
# pd | pen_color | pen_width | pencolor | pendown | pensize | penup | pos | position | pu
#
# re | right | rt | seth | setheading | setpos | setposition | setx | sety | shape
#
# showturtle | speed | st | svg_lines_string | time | turtle_degree | turtle_pos | turtle_shape | turtle_speed | up
#
# width | window_height | window_size | window_width | write | xcor | ycor
# ```

# %% [markdown]
# # Beispiel: Drei Linien
#
# Starte jede neue Zeichnung mit `it()`

# %%
it()
# 50 Schritte gerade aus
forward(50)
# drehen 60 Grad nach links
left(60)
 # 40 Schritte gerade aus
forward(40)
# drehen 60 Grad nach rechts
right(60)
# 60 Schritte gerade aus
forward(60)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="365.359" y2="180.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="365.359" y1="180.0" x2="365.359" y2="120.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,365.359,120.0) translate(347.359, 102.0)">
# ...

# %% [markdown]
# # 1) Quadrat
#
# ![image.png](data:image/png;base64,...)

# %%
# TODO: Ein Quadrat zeichen
# HINWEISE:
# - Ein Quadrat hat vier Seiten und vier Ecken mit Winkeln von 90 Grad
# - Jede Seite hat die gleiche Länge


it()
# Seite 1
# 50 Schritte gerade aus

# drehen 90 Grad nach links

# Seite 2
# 50 Schritte gerade aus

# drehen 90 Grad nach links

# Seite 3
# 50 Schritte gerade aus

# drehen 90 Grad nach links

# Seite 4
# 50 Schritte gerade aus

# drehen 90 Grad nach links

# %% [markdown]
# # 2) Rechteck
#
# ![image.png](data:image/png;base64,...)

# %%
# TODO: Ein Rechteck zeichen
# HINWEISE:
# - Ein Rechteck hat vier Seiten und vier Ecken mit Winkeln von 90 Grad
# - Die erste und dritte Seite des Rechtecks sind die gleiche Länge
# - Die zweite und vierte Seite des Rechtecks sind die gleiche Länge

it()
# 100 Schritte gerade aus

# drehen 90 Grad nach links

# 50 Schritte gerade aus

# drehen 90 Grad nach links

# 100 Schritte gerade aus

# drehen 90 Grad nach links

# 50 Schritte gerade aus

# drehen 90 Grad nach links
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %% [markdown]
# # 3) Drei Quadrate
#
# ![image.png](data:image/png;base64,...)

# %%
# TODO: Ein Quadrat zeichen
# HINWEISE:
# - Ein Quadrat hat vier Seiten und vier Ecken mit Winkeln von 90 Grad
# - Jede Seite hat die gleiche Länge


it()
# Zeichne Quadrat 1

# drehen 20 Grad nach links

# Zeichne Quadrat 3

# drehen 20 Grad nach links

# Zeichne Quadrat 3

# drehen 20 Grad nach links

# %% [markdown]
# # Extra: 4) Quadrat mit Input

# %%
# TODO: Ändere den Code von `1) Quadrat`, so dass du die Länge der Seite des Quadrats über die Input eingibst.

# HINWEISE:
# - Verwende die Codezeile von "Exercise 1 - Intro", `seitenlaenge = float(input("Geb die Seite eines Quadrats in Zentimetern ein: "))`
# - Verwende den Code von Übung "1) Quadrat" oben und ändere `50` auf `seitenlaenge`

it()

# %% [markdown]
# # Extra: 5) Rechteck mit Input

# %%
# TODO: Ändere den Code von `4) Quadrat mit Input`, so dass du die zwei Längen der Seiten des Rechtecks über die Input eingibst.

# HINWEISE:
# - Verwende zweimal die Codezeile von "Exercise 1 - Intro", die startet `seitenlaenge = float(input(....`
# - Zuerst definierst du `seitenlaenge1`, dann `seitenlaenge2`
# - Verwende den Code von Übung "2) Rechteck" oben. Ändere `50` auf `seitenlaenge1` und `100` auf `seitenlaenge2`

it()
seitenlaenge1 = #
seitenlaenge2 = #

# %% [markdown]
# # Extra: 6) Drei Quadrate mit Input

# %%
# TODO: Ändere den Code von `3) Quadrate`, so dass du die Länge der Seite des Quadrats und den Drehwinkel zwischen den Quadraten über die Input eingibst.

# HINWEISE:
# - Verwende die Codezeile von "Exercise 1 - Intro", die startet `seitenlaenge = float(input(....`
# - Hier muss du zwei Variabeln definieren: `seitenlänge` und `winkel`
# - Verwende den Code von der Übung "3) Drei Quadrate" oben und pass es entsprechend an.

it()
